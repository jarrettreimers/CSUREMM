# %% [markdown]
# ## First Attempt
#
# This is slightly wrong but I still don't know why the objective function can be negative

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np

# %%
stations = ['station 1', 'station 2', 'station 3', 'station 4', 'station 5']
start_levels = {'station 1': 21, 'station 2': 3, 'station 3': 0, 'station 4': 48, 'station 5': 9}
optimal_levels = {'station 1': 15, 'station 2': 12, 'station 3': 18, 'station 4': 12, 'station 5': 24}
over_stations, under_stations = [], []

# fill over, under stations
for station in stations:
    if start_levels[station] >= optimal_levels[station]:
        over_stations.append(station)
    elif start_levels[station] <= optimal_levels[station]:
        under_stations.append(station)
        
T = 10 # number of time steps
K = 2 # number of trucks
L = 3 # number of bikes that can be moved in one time step

# %%
model = gp.Model("bike_rebalancing")
# N = G.nodes()
# What is this for??

# %%
'''
decision variables: 
x: whether or not truck k is at station s at time t
y: number of bikes available to truck k is at station s at time t
b: number of bikes in truck k at time t
'''
x, y, b = {}, {}, {}

for t in range(1, T+1):
    for k in range(1, K+1):
        for s in stations:
            x[s,t,k] = model.addVar(name="x_%s,%s,%s"%(s,t,k), vtype=GRB.BINARY)
            y[s,t,k] = model.addVar(name="y_%s,%s,%s"%(s,t,k), vtype=GRB.INTEGER)
        b[t,k] = model.addVar(name="b_%s,%s"%(t,k), vtype=GRB.INTEGER)

model.update()

# %%
# objective function

objective = gp.quicksum((optimal_levels[s] - y[s, T, 1]) for s in under_stations) \
            + gp.quicksum((y[s,T,1] - optimal_levels[s]) for s in over_stations)
model.setObjective(objective, sense=GRB.MINIMIZE)

# %%
# constraints

# each truck must be at exactly 1 station always
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(x[s,t,k] for s in stations) == 1)

# initiate
for s in stations:
    model.addConstr(sum(y[s,1,k] for k in range(1, K+1)) == start_levels[s])

# rebalancing can only bring a station closer to optimal level
for t in range(1, T+1):
    for s in over_stations:
        model.addConstr(optimal_levels[s] <= sum(y[s,t,k] for k in range(1, K+1)))
        model.addConstr(sum(y[s,t,k] for k in range(1, K+1)) <= start_levels[s])
    for s in under_stations:
        model.addConstr(start_levels[s] <= sum(y[s,t,k] for k in range(1, K+1)))
        model.addConstr(sum(y[s,t,k] for k in range(1, K+1)) <= optimal_levels[s])

# total number of bikes is constant
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(y[s,t,k] for s in stations) + b[t,k] == sum(y[s,1,k] for s in stations) + b[1,k])

# can move only when truck is at station, number of bikes moved is bounded by 
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(y[s,t,k] - y[s,t-1,k] <= L * x[s,t,k])
            model.addConstr(y[s,t-1,k] - y[s,t,k] <= L * x[s,t,k])

# add last constraint later...

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 17.7.0 17G14042)
#
# CPU model: Intel(R) Core(TM) i5-4250U CPU @ 1.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 325 rows, 220 columns and 1066 nonzeros
# Model fingerprint: 0x8427abed
# Variable types: 0 continuous, 220 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 72.0000000
# Presolve removed 55 rows and 38 columns
# Presolve time: 0.00s
# Presolved: 270 rows, 182 columns, 770 nonzeros
# Variable types: 0 continuous, 182 integer (88 binary)
#
# Root relaxation: objective -1.200000e+01, 184 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     -12.0000000  -12.00000  0.00%     -    0s
#
# Explored 1 nodes (184 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -12 72
# No other solutions better than -12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.200000000000e+01, best bound -1.200000000000e+01, gap 0.0000%

# %% [markdown]
# ## Slight Fix... without dummy

# %% [markdown]
# If we want, we can have random starting and optimal levels...

# %%
import random

B = 200 # total bikes
S = 8 # total stations

stations = ['station {}'.format(s) for s in range(1,S+1)]
start_levels = {}
optimal_levels = {}
for station in stations:
    start_levels[station] = 0
    optimal_levels[station] = 0
for _ in range(B):
    start_levels[random.choice(stations)] += 1
    optimal_levels[random.choice(stations)] += 1

# %% [markdown]
# Now, we run the simulation:

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np

stations = ['station 1', 'station 2', 'station 3', 'station 4', 'station 5']
start_levels = {'station 1': 30, 'station 2': 30, 'station 3': 0, 'station 4': 0, 'station 5': 15}
optimal_levels = {'station 1': 15, 'station 2': 15, 'station 3': 15, 'station 4': 15, 'station 5': 15}
over_stations, under_stations, balanced_stations = [], [], []

# Fill over and under stations
for station in stations:
    if start_levels[station] > optimal_levels[station]:
        over_stations.append(station)
    elif start_levels[station] < optimal_levels[station]:
        under_stations.append(station)
    else:
        balanced_stations.append(station)
        
T = 20 # Number of time steps
K = 2 # Number of trucks
L = 3 # Number of bikes that can be moved in one time step

model = gp.Model("bike_rebalancing")

# Decision variables
x, y, b = {}, {}, {}
for t in range(1, T+1):
    for k in range(1, K+1):
        for s in stations:
            x[s, t, k] = model.addVar(name="x_%s,%s,%s" % (s, t, k), vtype=GRB.BINARY)
            y[s, t, k] = model.addVar(name="y_%s,%s,%s" % (s, t, k), vtype=GRB.INTEGER)
        b[t, k] = model.addVar(name="b_%s,%s" % (t, k), vtype=GRB.INTEGER)

# Auxiliary variables for absolute deviation
deviation = {}
for s in stations:
    deviation[s] = model.addVar(name="deviation_%s" % s, vtype=GRB.INTEGER)

model.update()

# Objective function: minimize total absolute deviation from optimal levels
objective = gp.quicksum(deviation[s] for s in stations)
model.setObjective(objective, sense=GRB.MINIMIZE)

# Constraints

# Each truck must be at exactly 1 station always
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(x[s, t, k] for s in stations) == 1)

# Initialize bike levels at time 1
for s in stations:
    model.addConstr(sum(y[s, 1, k] for k in range(1, K+1)) == start_levels[s])

# Rebalancing can only bring a station closer to optimal level
for t in range(1, T+1):
    for s in over_stations:
        model.addConstr(optimal_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= start_levels[s])
    for s in under_stations:
        model.addConstr(start_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= optimal_levels[s])
    for s in balanced_stations:
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) == start_levels[s])

# Total number of bikes is constant
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(y[s, t, k] for s in stations) + b[t, k] == sum(y[s, 1, k] for s in stations) + b[1, k])

# Can move only when truck is at station; number of bikes moved is bounded
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(y[s, t, k] - y[s, t-1, k] <= L * x[s, t, k])
            model.addConstr(y[s, t-1, k] - y[s, t, k] <= L * x[s, t, k])

# Constraint 8 in paper
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in over_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L + (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L - (y[s,t,k] - y[s,t-1,k]))
        for s in under_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L - (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L + (y[s,t,k] - y[s,t-1,k]))

# TEST: each truck can only house L bikes
for k in range(1, K+1):
    for t in range(1,T+1):
        model.addConstr(b[t,k] <= L)

# Absolute deviation constraints
for s in stations:
    model.addConstr(deviation[s] >= optimal_levels[s] - sum(y[s, T, k] for k in range(1, K+1)))
    model.addConstr(deviation[s] >= sum(y[s, T, k] for k in range(1, K+1)) - optimal_levels[s])

model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 17.7.0 17G14042)
#
# CPU model: Intel(R) Core(TM) i5-4250U CPU @ 1.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 999 rows, 445 columns and 3452 nonzeros
# Model fingerprint: 0x467f4653
# Variable types: 0 continuous, 445 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 285 rows and 31 columns
# Presolve time: 0.02s
# Presolved: 714 rows, 414 columns, 2522 nonzeros
# Variable types: 0 continuous, 414 integer (196 binary)
# Found heuristic solution: objective 57.0000000
# Found heuristic solution: objective 54.0000000
#
# Root relaxation: objective 0.000000e+00, 392 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   79   54.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   91   54.00000    0.00000   100%     -    0s
# H    0     0                      42.0000000    0.00000   100%     -    0s
#      0     0    0.00000    0   93   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   97   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   73   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0  105   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   32   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   45   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   36   42.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   36   42.00000    0.00000   100%     -    0s
# H    0     0                      30.0000000    0.00000   100%     -    0s
# H    0     0                      24.0000000    0.00000   100%     -    0s
#
# Interrupt request received
# H    0     2                      18.0000000    0.00000   100%     -    0s
#      0     2    0.00000    0   22   18.00000    0.00000   100%     -    0s
# H   64   120                      15.0000000    0.00000   100%  43.8    0s
# H 2337  1487                      12.0000000    0.00000   100%  33.2    4s
# H 2721  1637                       9.0000000    0.00000   100%  34.8    5s
# H 3210  1528                       6.0000000    0.00000   100%  32.9    5s
# H 3277  1310                       3.0000000    0.00000   100%  33.5    5s
# H 3405   274                       0.0000000    0.00000  0.00%  35.0    6s
#
# Cutting planes:
#   Gomory: 11
#   MIR: 16
#   Flow cover: 18
#   Zero half: 1
#
# Explored 3504 nodes (127755 simplex iterations) in 6.13 seconds (2.97 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 0 3 6 ... 42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%

# %% [markdown]
# # Now adding dummy

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np

# %% [markdown]
# ### Random positions and levels

# %%
import random

B = 300 # total bikes
S = 8 # total stations

stations = ['station {}'.format(s) for s in range(1,S+1)]
start_levels = {}
optimal_levels = {}
for station in stations:
    start_levels[station] = 0
    optimal_levels[station] = 0
for _ in range(B):
    start_levels[random.choice(stations)] += 1
    optimal_levels[random.choice(stations)] += 1

positions = {}
for station in stations:
    positions[station] = (random.random(), random.random())

neighbors = {}
for s in stations:
    limit = 0.3
    neighbors[s] = [s1 for s1 in stations if np.linalg.norm(np.array(positions[s] - np.array(positions[s1]))) < 0.7]

# %% [markdown]
# ### Set positions and levels

# %%
stations = ['station 1', 'station 2', 'station 3', 'station 4']
start_levels = {'station 1': 30, 'station 2': 15, 'station 3': 15, 'station 4': 0}
optimal_levels = {'station 1': 15, 'station 2': 15, 'station 3': 15, 'station 4': 15}

positions = {'station 1': (-1.0, -1.0), 'station 2': (1.0, -1.0), 'station 3': (-1.0, 1.0), 'station 4': (1.0, 1.0)}
neighbors = {'station 1': ['station 1', 'station 2', 'station 3'],
           'station 2': ['station 1', 'station 2', 'station 4'],
           'station 3':['station 1', 'station 3', 'station 4'],
           'station 4':['station 2', 'station 3', 'station 4']
           }

# %% [markdown]
# ### Rest of model

# %%
over_stations, under_stations, balanced_stations = [], [], []
# Fill over and under stations
for station in stations:
    if start_levels[station] > optimal_levels[station]:
        over_stations.append(station)
    elif start_levels[station] < optimal_levels[station]:
        under_stations.append(station)
    else:
        balanced_stations.append(station)
        
T = 20 # Number of time steps
K = 2 # Number of trucks
L = 3 # Number of bikes that can be moved in one time step

model = gp.Model("bike_rebalancing")

# Decision variables
x, y, b = {}, {}, {}
for t in range(1, T+1):
    for k in range(1, K+1):
        for s in stations:
            x[s, t, k] = model.addVar(name="x_%s,%s,%s" % (s, t, k), vtype=GRB.BINARY)
            y[s, t, k] = model.addVar(name="y_%s,%s,%s" % (s, t, k), vtype=GRB.INTEGER)
        b[t, k] = model.addVar(name="b_%s,%s" % (t, k), vtype=GRB.INTEGER)

# Auxiliary variables for absolute deviation
deviation = {}
for s in stations:
    deviation[s] = model.addVar(name="deviation_%s" % s, vtype=GRB.INTEGER)

model.update()

# Objective function: minimize total absolute deviation from optimal levels
objective = gp.quicksum(deviation[s] for s in stations)
model.setObjective(objective, sense=GRB.MINIMIZE)

# Constraints:

# Constraint 1: can only move to an adjacent station
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(x[s,t,k] <= x[s,t-1,k] + gp.quicksum(x[s1,t-1,k] for s1 in neighbors[s]))


# Constraint 2: each truck must be at exactly 1 station always
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(x[s, t, k] for s in stations) == 1)

# Constraint 3: initialize bike levels at time 1
for s in stations:
    model.addConstr(sum(y[s, 1, k] for k in range(1, K+1)) == start_levels[s])

# Constraint 4 & 5: rebalancing can only bring a station closer to optimal level
for t in range(1, T+1):
    for s in over_stations:
        model.addConstr(optimal_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= start_levels[s])
    for s in under_stations:
        model.addConstr(start_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= optimal_levels[s])
    for s in balanced_stations:
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) == start_levels[s])

# Constraint 6: total number of bikes is constant
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(y[s, t, k] for s in stations) + b[t, k] == sum(y[s, 1, k] for s in stations) + b[1, k])

# Constraint 7: can move only when truck is at station; number of bikes moved is bounded
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(y[s, t, k] - y[s, t-1, k] <= L * x[s, t, k])
            model.addConstr(y[s, t-1, k] - y[s, t, k] <= L * x[s, t, k])

# Constraint 8: can either travel or load/unload, not both
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in over_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L + (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L - (y[s,t,k] - y[s,t-1,k]))
        for s in under_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L - (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L + (y[s,t,k] - y[s,t-1,k]))

# TEST: each truck can only house L bikes
for k in range(1, K+1):
    for t in range(1,T+1):
        model.addConstr(b[t,k] <= L)

# Absolute deviation constraints
for s in stations:
    model.addConstr(deviation[s] >= optimal_levels[s] - sum(y[s, T, k] for k in range(1, K+1)))
    model.addConstr(deviation[s] >= sum(y[s, T, k] for k in range(1, K+1)) - optimal_levels[s])

# At beginning and end, there must be no bikes in trucks
model.addConstr(gp.quicksum(b[T, k] for k in range(1, K+1)) == 0)
model.addConstr(gp.quicksum(b[1, k] for k in range(1, K+1)) == 0)

model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 17.7.0 17G14042)
#
# CPU model: Intel(R) Core(TM) i5-4250U CPU @ 1.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 1986 rows, 688 columns and 7756 nonzeros
# Model fingerprint: 0x5f4d5be8
# Variable types: 0 continuous, 688 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Presolve removed 389 rows and 5 columns
# Presolve time: 0.07s
# Presolved: 1597 rows, 683 columns, 6138 nonzeros
# Variable types: 0 continuous, 683 integer (321 binary)
# Found heuristic solution: objective 46.0000000
#
# Root relaxation: objective 0.000000e+00, 875 iterations, 0.08 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  147   46.00000    0.00000   100%     -    0s
#      0     0    0.00000    0  132   46.00000    0.00000   100%     -    0s
#      0     0    0.00000    0   96   46.00000    0.00000   100%     -    1s
#      0     0    0.00000    0  109   46.00000    0.00000   100%     -    1s
#      0     0    0.00000    0   92   46.00000    0.00000   100%     -    1s
# H    0     0                      44.0000000    0.00000   100%     -    1s
#      0     0    0.00000    0   92   44.00000    0.00000   100%     -    1s
#      0     0    0.00000    0  106   44.00000    0.00000   100%     -    1s
#      0     0    0.00000    0   63   44.00000    0.00000   100%     -    1s
#
# Interrupt request received
#      0     2    0.00000    0   46   44.00000    0.00000   100%     -    1s
# H   56    92                      22.0000000    0.00000   100%  96.5    2s
# H  876   617                      14.0000000    0.00000   100%  58.5    3s
#
# Cutting planes:
#   Gomory: 22
#   MIR: 19
#   Flow cover: 23
#   Zero half: 24
#   RLT: 3
#
# Explored 885 nodes (64719 simplex iterations) in 4.36 seconds (2.62 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 4: 14 22 44 46
#
# Solve interrupted
# Best objective 1.400000000000e+01, best bound 0.000000000000e+00, gap 100.0000%

# %%
x
# Out:
# {('station 1', 1, 1): <gurobi.Var x_station 1,1,1 (value -0.0)>,
#  ('station 2', 1, 1): <gurobi.Var x_station 2,1,1 (value -0.0)>,
#  ('station 3', 1, 1): <gurobi.Var x_station 3,1,1 (value -0.0)>,
#  ('station 4', 1, 1): <gurobi.Var x_station 4,1,1 (value -0.0)>,
#  ('station 5', 1, 1): <gurobi.Var x_station 5,1,1 (value -0.0)>,
#  ('station 6', 1, 1): <gurobi.Var x_station 6,1,1 (value 1.0)>,
#  ('station 7', 1, 1): <gurobi.Var x_station 7,1,1 (value -0.0)>,
#  ('station 8', 1, 1): <gurobi.Var x_station 8,1,1 (value -0.0)>,
#  ('station 1', 1, 2): <gurobi.Var x_station 1,1,2 (value 0.0)>,
#  ('station 2', 1, 2): <gurobi.Var x_station 2,1,2 (value -0.0)>,
#  ('station 3', 1, 2): <gurobi.Var x_station 3,1,2 (value 0.0)>,
#  ('station 4', 1, 2): <gurobi.Var x_station 4,1,2 (value 1.0)>,
#  ('station 5', 1, 2): <gurobi.Var x_station 5,1,2 (value -0.0)>,
#  ('station 6', 1, 2): <gurobi.Var x_station 6,1,2 (value -0.0)>,
#  ('station 7', 1, 2): <gurobi.Var x_station 7,1,2 (value -0.0)>,
#  ('station 8', 1, 2): <gurobi.Var x_station 8,1,2 (value -0.0)>,
#  ('station 1', 2, 1): <gurobi.Var x_station 1,2,1 (value -0.0)>,
#  ('station 2', 2, 1): <gurobi.Var x_station 2,2,1 (value -0.0)>,
#  ('station 3', 2, 1): <gurobi.Var x_station 3,2,1 (value -0.0)>,
#  ('station 4', 2, 1): <gurobi.Var x_station 4,2,1 (value 1.0)>,
#  ('station 5', 2, 1): <gurobi.Var x_station 5,2,1 (value -0.0)>,
#  ('station 6', 2, 1): <gurobi.Var x_station 6,2,1 (value 0.0)>,
#  ('station 7', 2, 1): <gurobi.Var x_station 7,2,1 (value -0.0)>,
#  ('station 8', 2, 1): <gurobi.Var x_station 8,2,1 (value -0.0)>,
#  ('station 1', 2, 2): <gurobi.Var x_station 1,2,2 (value 1.0)>,
#  ('station 2', 2, 2): <gurobi.Var x_station 2,2,2 (value -0.0)>,
#  ('station 3', 2, 2): <gurobi.Var x_station 3,2,2 (value 0.0)>,
#  ('station 4', 2, 2): <gurobi.Var x_station 4,2,2 (value -0.0)>,
#  ('station 5', 2, 2): <gurobi.Var x_station 5,2,2 (value -0.0)>,
#  ('station 6', 2, 2): <gurobi.Var x_station 6,2,2 (value -0.0)>,
#  ('station 7', 2, 2): <gurobi.Var x_station 7,2,2 (value 0.0)>,
#  ('station 8', 2, 2): <gurobi.Var x_station 8,2,2 (value -0.0)>,
#  ('station 1', 3, 1): <gurobi.Var x_station 1,3,1 (value -0.0)>,
#  ('station 2', 3, 1): <gurobi.Var x_station 2,3,1 (value -0.0)>,
#  ('station 3', 3, 1): <gurobi.Var x_station 3,3,1 (value -0.0)>,
#  ('station 4', 3, 1): <gurobi.Var x_station 4,3,1 (value 1.0)>,
#  ('station 5', 3, 1): <gurobi.Var x_station 5,3,1 (value -0.0)>,
#  ('station 6', 3, 1): <gurobi.Var x_station 6,3,1 (value -0.0)>,
#  ('station 7', 3, 1): <gurobi.Var x_station 7,3,1 (value -0.0)>,
#  ('station 8', 3, 1): <gurobi.Var x_station 8,3,1 (value -0.0)>,
#  ('station 1', 3, 2): <gurobi.Var x_station 1,3,2 (value 1.0)>,
#  ('station 2', 3, 2): <gurobi.Var x_station 2,3,2 (value -0.0)>,
#  ('station 3', 3, 2): <gurobi.Var x_station 3,3,2 (value 0.0)>,
#  ('station 4', 3, 2): <gurobi.Var x_station 4,3,2 (value -0.0)>,
#  ('station 5', 3, 2): <gurobi.Var x_station 5,3,2 (value -0.0)>,
#  ('station 6', 3, 2): <gurobi.Var x_station 6,3,2 (value -0.0)>,
#  ('station 7', 3, 2): <gurobi.Var x_station 7,3,2 (value -0.0)>,
#  ('station 8', 3, 2): <gurobi.Var x_station 8,3,2 (value -0.0)>,
#  ('station 1', 4, 1): <gurobi.Var x_station 1,4,1 (value -0.0)>,
#  ('station 2', 4, 1): <gurobi.Var x_station 2,4,1 (value -0.0)>,
#  ('station 3', 4, 1): <gurobi.Var x_station 3,4,1 (value -0.0)>,
#  ('station 4', 4, 1): <gurobi.Var x_station 4,4,1 (value -0.0)>,
#  ('station 5', 4, 1): <gurobi.Var x_station 5,4,1 (value -0.0)>,
#  ('station 6', 4, 1): <gurobi.Var x_station 6,4,1 (value -0.0)>,
#  ('station 7', 4, 1): <gurobi.Var x_station 7,4,1 (value 1.0)>,
#  ('station 8', 4, 1): <gurobi.Var x_station 8,4,1 (value -0.0)>,
#  ('station 1', 4, 2): <gurobi.Var x_station 1,4,2 (value 1.0)>,
#  ('station 2', 4, 2): <gurobi.Var x_station 2,4,2 (value -0.0)>,
#  ('station 3', 4, 2): <gurobi.Var x_station 3,4,2 (value 0.0)>,
#  ('station 4', 4, 2): <gurobi.Var x_station 4,4,2 (value -0.0)>,
#  ('station 5', 4, 2): <gurobi.Var x_station 5,4,2 (value -0.0)>,
#  ('station 6', 4, 2): <gurobi.Var x_station 6,4,2 (value -0.0)>,
#  ('station 7', 4, 2): <gurobi.Var x_station 7,4,2 (value -0.0)>,
#  ('station 8', 4, 2): <gurobi.Var x_station 8,4,2 (value -0.0)>,
#  ('station 1', 5, 1): <gurobi.Var x_station 1,5,1 (value -0.0)>,
#  ('station 2', 5, 1): <gurobi.Var x_station 2,5,1 (value -0.0)>,
#  ('station 3', 5, 1): <gurobi.Var x_station 3,5,1 (value -0.0)>,
#  ('station 4', 5, 1): <gurobi.Var x_station 4,5,1 (value -0.0)>,
#  ('station 5', 5, 1): <gurobi.Var x_station 5,5,1 (value -0.0)>,
#  ('station 6', 5, 1): <gurobi.Var x_station 6,5,1 (value -0.0)>,
#  ('station 7', 5, 1): <gurobi.Var x_station 7,5,1 (value 1.0)>,
#  ('station 8', 5, 1): <gurobi.Var x_station 8,5,1 (value -0.0)>,
#  ('station 1', 5, 2): <gurobi.Var x_station 1,5,2 (value 0.0)>,
#  ('station 2', 5, 2): <gurobi.Var x_station 2,5,2 (value -0.0)>,
#  ('station 3', 5, 2): <gurobi.Var x_station 3,5,2 (value -0.0)>,
#  ('station 4', 5, 2): <gurobi.Var x_station 4,5,2 (value -0.0)>,
#  ('station 5', 5, 2): <gurobi.Var x_station 5,5,2 (value 1.0)>,
#  ('station 6', 5, 2): <gurobi.Var x_station 6,5,2 (value -0.0)>,
#  ('station 7', 5, 2): <gurobi.Var x_station 7,5,2 (value 0.0)>,
#  ('station 8', 5, 2): <gurobi.Var x_station 8,5,2 (value -0.0)>,
#  ('station 1', 6, 1): <gurobi.Var x_station 1,6,1 (value -0.0)>,
#  ('station 2', 6, 1): <gurobi.Var x_station 2,6,1 (value -0.0)>,
#  ('station 3', 6, 1): <gurobi.Var x_station 3,6,1 (value 1.0)>,
#  ('station 4', 6, 1): <gurobi.Var x_station 4,6,1 (value -0.0)>,
#  ('station 5', 6, 1): <gurobi.Var x_station 5,6,1 (value -0.0)>,
#  ('station 6', 6, 1): <gurobi.Var x_station 6,6,1 (value -0.0)>,
#  ('station 7', 6, 1): <gurobi.Var x_station 7,6,1 (value -0.0)>,
#  ('station 8', 6, 1): <gurobi.Var x_station 8,6,1 (value -0.0)>,
#  ('station 1', 6, 2): <gurobi.Var x_station 1,6,2 (value 0.0)>,
#  ('station 2', 6, 2): <gurobi.Var x_station 2,6,2 (value -0.0)>,
#  ('station 3', 6, 2): <gurobi.Var x_station 3,6,2 (value -0.0)>,
#  ('station 4', 6, 2): <gurobi.Var x_station 4,6,2 (value -0.0)>,
#  ('station 5', 6, 2): <gurobi.Var x_station 5,6,2 (value 1.0)>,
#  ('station 6', 6, 2): <gurobi.Var x_station 6,6,2 (value 0.0)>,
#  ('station 7', 6, 2): <gurobi.Var x_station 7,6,2 (value -0.0)>,
#  ('station 8', 6, 2): <gurobi.Var x_station 8,6,2 (value -0.0)>,
#  ('station 1', 7, 1): <gurobi.Var x_station 1,7,1 (value -0.0)>,
#  ('station 2', 7, 1): <gurobi.Var x_station 2,7,1 (value -0.0)>,
#  ('station 3', 7, 1): <gurobi.Var x_station 3,7,1 (value 1.0)>,
#  ('station 4', 7, 1): <gurobi.Var x_station 4,7,1 (value -0.0)>,
#  ('station 5', 7, 1): <gurobi.Var x_station 5,7,1 (value -0.0)>,
#  ('station 6', 7, 1): <gurobi.Var x_station 6,7,1 (value -0.0)>,
#  ('station 7', 7, 1): <gurobi.Var x_station 7,7,1 (value -0.0)>,
#  ('station 8', 7, 1): <gurobi.Var x_station 8,7,1 (value -0.0)>,
#  ('station 1', 7, 2): <gurobi.Var x_station 1,7,2 (value -0.0)>,
#  ('station 2', 7, 2): <gurobi.Var x_station 2,7,2 (value -0.0)>,
#  ('station 3', 7, 2): <gurobi.Var x_station 3,7,2 (value -0.0)>,
#  ('station 4', 7, 2): <gurobi.Var x_station 4,7,2 (value -0.0)>,
#  ('station 5', 7, 2): <gurobi.Var x_station 5,7,2 (value -0.0)>,
#  ('station 6', 7, 2): <gurobi.Var x_station 6,7,2 (value 0.0)>,
#  ('station 7', 7, 2): <gurobi.Var x_station 7,7,2 (value -0.0)>,
#  ('station 8', 7, 2): <gurobi.Var x_station 8,7,2 (value 1.0)>,
#  ('station 1', 8, 1): <gurobi.Var x_station 1,8,1 (value -0.0)>,
#  ('station 2', 8, 1): <gurobi.Var x_station 2,8,1 (value -0.0)>,
#  ('station 3', 8, 1): <gurobi.Var x_station 3,8,1 (value -0.0)>,
#  ('station 4', 8, 1): <gurobi.Var x_station 4,8,1 (value -0.0)>,
#  ('station 5', 8, 1): <gurobi.Var x_station 5,8,1 (value -0.0)>,
#  ('station 6', 8, 1): <gurobi.Var x_station 6,8,1 (value -0.0)>,
#  ('station 7', 8, 1): <gurobi.Var x_station 7,8,1 (value 1.0)>,
#  ('station 8', 8, 1): <gurobi.Var x_station 8,8,1 (value -0.0)>,
#  ('station 1', 8, 2): <gurobi.Var x_station 1,8,2 (value -0.0)>,
#  ('station 2', 8, 2): <gurobi.Var x_station 2,8,2 (value -0.0)>,
#  ('station 3', 8, 2): <gurobi.Var x_station 3,8,2 (value -0.0)>,
#  ('station 4', 8, 2): <gurobi.Var x_station 4,8,2 (value -0.0)>,
#  ('station 5', 8, 2): <gurobi.Var x_station 5,8,2 (value -0.0)>,
#  ('station 6', 8, 2): <gurobi.Var x_station 6,8,2 (value -0.0)>,
#  ('station 7', 8, 2): <gurobi.Var x_station 7,8,2 (value -0.0)>,
#  ('station 8', 8, 2): <gurobi.Var x_station 8,8,2 (value 1.0)>,
#  ('station 1', 9, 1): <gurobi.Var x_station 1,9,1 (value -0.0)>,
#  ('station 2', 9, 1): <gurobi.Var x_station 2,9,1 (value -0.0)>,
#  ('station 3', 9, 1): <gurobi.Var x_station 3,9,1 (value -0.0)>,
#  ('station 4', 9, 1): <gurobi.Var x_station 4,9,1 (value 1.0)>,
#  ('station 5', 9, 1): <gurobi.Var x_station 5,9,1 (value -0.0)>,
#  ('station 6', 9, 1): <gurobi.Var x_station 6,9,1 (value -0.0)>,
#  ('station 7', 9, 1): <gurobi.Var x_station 7,9,1 (value -0.0)>,
#  ('station 8', 9, 1): <gurobi.Var x_station 8,9,1 (value -0.0)>,
#  ('station 1', 9, 2): <gurobi.Var x_station 1,9,2 (value -0.0)>,
#  ('station 2', 9, 2): <gurobi.Var x_station 2,9,2 (value -0.0)>,
#  ('station 3', 9, 2): <gurobi.Var x_station 3,9,2 (value -0.0)>,
#  ('station 4', 9, 2): <gurobi.Var x_station 4,9,2 (value -0.0)>,
#  ('station 5', 9, 2): <gurobi.Var x_station 5,9,2 (value -0.0)>,
#  ('station 6', 9, 2): <gurobi.Var x_station 6,9,2 (value 1.0)>,
#  ('station 7', 9, 2): <gurobi.Var x_station 7,9,2 (value -0.0)>,
#  ('station 8', 9, 2): <gurobi.Var x_station 8,9,2 (value -0.0)>,
#  ('station 1', 10, 1): <gurobi.Var x_station 1,10,1 (value -0.0)>,
#  ('station 2', 10, 1): <gurobi.Var x_station 2,10,1 (value 1.0)>,
#  ('station 3', 10, 1): <gurobi.Var x_station 3,10,1 (value -0.0)>,
#  ('station 4', 10, 1): <gurobi.Var x_station 4,10,1 (value -0.0)>,
#  ('station 5', 10, 1): <gurobi.Var x_station 5,10,1 (value -0.0)>,
#  ('station 6', 10, 1): <gurobi.Var x_station 6,10,1 (value -0.0)>,
#  ('station 7', 10, 1): <gurobi.Var x_station 7,10,1 (value -0.0)>,
#  ('station 8', 10, 1): <gurobi.Var x_station 8,10,1 (value -0.0)>,
#  ('station 1', 10, 2): <gurobi.Var x_station 1,10,2 (value -0.0)>,
#  ('station 2', 10, 2): <gurobi.Var x_station 2,10,2 (value -0.0)>,
#  ('station 3', 10, 2): <gurobi.Var x_station 3,10,2 (value -0.0)>,
#  ('station 4', 10, 2): <gurobi.Var x_station 4,10,2 (value -0.0)>,
#  ('station 5', 10, 2): <gurobi.Var x_station 5,10,2 (value -0.0)>,
#  ('station 6', 10, 2): <gurobi.Var x_station 6,10,2 (value 1.0)>,
#  ('station 7', 10, 2): <gurobi.Var x_station 7,10,2 (value -0.0)>,
#  ('station 8', 10, 2): <gurobi.Var x_station 8,10,2 (value -0.0)>,
#  ('station 1', 11, 1): <gurobi.Var x_station 1,11,1 (value -0.0)>,
#  ('station 2', 11, 1): <gurobi.Var x_station 2,11,1 (value 1.0)>,
#  ('station 3', 11, 1): <gurobi.Var x_station 3,11,1 (value -0.0)>,
#  ('station 4', 11, 1): <gurobi.Var x_station 4,11,1 (value -0.0)>,
#  ('station 5', 11, 1): <gurobi.Var x_station 5,11,1 (value -0.0)>,
#  ('station 6', 11, 1): <gurobi.Var x_station 6,11,1 (value -0.0)>,
#  ('station 7', 11, 1): <gurobi.Var x_station 7,11,1 (value -0.0)>,
#  ('station 8', 11, 1): <gurobi.Var x_station 8,11,1 (value -0.0)>,
#  ('station 1', 11, 2): <gurobi.Var x_station 1,11,2 (value -0.0)>,
#  ('station 2', 11, 2): <gurobi.Var x_station 2,11,2 (value -0.0)>,
#  ('station 3', 11, 2): <gurobi.Var x_station 3,11,2 (value -0.0)>,
#  ('station 4', 11, 2): <gurobi.Var x_station 4,11,2 (value 1.0)>,
#  ('station 5', 11, 2): <gurobi.Var x_station 5,11,2 (value -0.0)>,
#  ('station 6', 11, 2): <gurobi.Var x_station 6,11,2 (value -0.0)>,
#  ('station 7', 11, 2): <gurobi.Var x_station 7,11,2 (value -0.0)>,
#  ('station 8', 11, 2): <gurobi.Var x_station 8,11,2 (value -0.0)>,
#  ('station 1', 12, 1): <gurobi.Var x_station 1,12,1 (value -0.0)>,
#  ('station 2', 12, 1): <gurobi.Var x_station 2,12,1 (value -0.0)>,
#  ('station 3', 12, 1): <gurobi.Var x_station 3,12,1 (value -0.0)>,
#  ('station 4', 12, 1): <gurobi.Var x_station 4,12,1 (value 1.0)>,
#  ('station 5', 12, 1): <gurobi.Var x_station 5,12,1 (value -0.0)>,
#  ('station 6', 12, 1): <gurobi.Var x_station 6,12,1 (value -0.0)>,
#  ('station 7', 12, 1): <gurobi.Var x_station 7,12,1 (value -0.0)>,
#  ('station 8', 12, 1): <gurobi.Var x_station 8,12,1 (value -0.0)>,
#  ('station 1', 12, 2): <gurobi.Var x_station 1,12,2 (value -0.0)>,
#  ('station 2', 12, 2): <gurobi.Var x_station 2,12,2 (value -0.0)>,
#  ('station 3', 12, 2): <gurobi.Var x_station 3,12,2 (value -0.0)>,
#  ('station 4', 12, 2): <gurobi.Var x_station 4,12,2 (value -0.0)>,
#  ('station 5', 12, 2): <gurobi.Var x_station 5,12,2 (value 1.0)>,
#  ('station 6', 12, 2): <gurobi.Var x_station 6,12,2 (value -0.0)>,
#  ('station 7', 12, 2): <gurobi.Var x_station 7,12,2 (value -0.0)>,
#  ('station 8', 12, 2): <gurobi.Var x_station 8,12,2 (value -0.0)>,
#  ('station 1', 13, 1): <gurobi.Var x_station 1,13,1 (value -0.0)>,
#  ('station 2', 13, 1): <gurobi.Var x_station 2,13,1 (value -0.0)>,
#  ('station 3', 13, 1): <gurobi.Var x_station 3,13,1 (value -0.0)>,
#  ('station 4', 13, 1): <gurobi.Var x_station 4,13,1 (value 1.0)>,
#  ('station 5', 13, 1): <gurobi.Var x_station 5,13,1 (value -0.0)>,
#  ('station 6', 13, 1): <gurobi.Var x_station 6,13,1 (value -0.0)>,
#  ('station 7', 13, 1): <gurobi.Var x_station 7,13,1 (value -0.0)>,
#  ('station 8', 13, 1): <gurobi.Var x_station 8,13,1 (value -0.0)>,
#  ('station 1', 13, 2): <gurobi.Var x_station 1,13,2 (value -0.0)>,
#  ('station 2', 13, 2): <gurobi.Var x_station 2,13,2 (value -0.0)>,
#  ('station 3', 13, 2): <gurobi.Var x_station 3,13,2 (value -0.0)>,
#  ('station 4', 13, 2): <gurobi.Var x_station 4,13,2 (value 1.0)>,
#  ('station 5', 13, 2): <gurobi.Var x_station 5,13,2 (value -0.0)>,
#  ('station 6', 13, 2): <gurobi.Var x_station 6,13,2 (value -0.0)>,
#  ('station 7', 13, 2): <gurobi.Var x_station 7,13,2 (value -0.0)>,
#  ('station 8', 13, 2): <gurobi.Var x_station 8,13,2 (value -0.0)>,
#  ('station 1', 14, 1): <gurobi.Var x_station 1,14,1 (value 1.0)>,
#  ('station 2', 14, 1): <gurobi.Var x_station 2,14,1 (value -0.0)>,
#  ('station 3', 14, 1): <gurobi.Var x_station 3,14,1 (value -0.0)>,
#  ('station 4', 14, 1): <gurobi.Var x_station 4,14,1 (value -0.0)>,
#  ('station 5', 14, 1): <gurobi.Var x_station 5,14,1 (value -0.0)>,
#  ('station 6', 14, 1): <gurobi.Var x_station 6,14,1 (value -0.0)>,
#  ('station 7', 14, 1): <gurobi.Var x_station 7,14,1 (value -0.0)>,
#  ('station 8', 14, 1): <gurobi.Var x_station 8,14,1 (value -0.0)>,
#  ('station 1', 14, 2): <gurobi.Var x_station 1,14,2 (value 1.0)>,
#  ('station 2', 14, 2): <gurobi.Var x_station 2,14,2 (value 0.0)>,
#  ('station 3', 14, 2): <gurobi.Var x_station 3,14,2 (value -0.0)>,
#  ('station 4', 14, 2): <gurobi.Var x_station 4,14,2 (value -0.0)>,
#  ('station 5', 14, 2): <gurobi.Var x_station 5,14,2 (value -0.0)>,
#  ('station 6', 14, 2): <gurobi.Var x_station 6,14,2 (value 0.0)>,
#  ('station 7', 14, 2): <gurobi.Var x_station 7,14,2 (value -0.0)>,
#  ('station 8', 14, 2): <gurobi.Var x_station 8,14,2 (value -0.0)>,
#  ('station 1', 15, 1): <gurobi.Var x_station 1,15,1 (value 1.0)>,
#  ('station 2', 15, 1): <gurobi.Var x_station 2,15,1 (value -0.0)>,
#  ('station 3', 15, 1): <gurobi.Var x_station 3,15,1 (value -0.0)>,
#  ('station 4', 15, 1): <gurobi.Var x_station 4,15,1 (value -0.0)>,
#  ('station 5', 15, 1): <gurobi.Var x_station 5,15,1 (value -0.0)>,
#  ('station 6', 15, 1): <gurobi.Var x_station 6,15,1 (value -0.0)>,
#  ('station 7', 15, 1): <gurobi.Var x_station 7,15,1 (value -0.0)>,
#  ('station 8', 15, 1): <gurobi.Var x_station 8,15,1 (value -0.0)>,
#  ('station 1', 15, 2): <gurobi.Var x_station 1,15,2 (value 1.0)>,
#  ('station 2', 15, 2): <gurobi.Var x_station 2,15,2 (value -0.0)>,
#  ('station 3', 15, 2): <gurobi.Var x_station 3,15,2 (value -0.0)>,
#  ('station 4', 15, 2): <gurobi.Var x_station 4,15,2 (value -0.0)>,
#  ('station 5', 15, 2): <gurobi.Var x_station 5,15,2 (value -0.0)>,
#  ('station 6', 15, 2): <gurobi.Var x_station 6,15,2 (value 0.0)>,
#  ('station 7', 15, 2): <gurobi.Var x_station 7,15,2 (value -0.0)>,
#  ('station 8', 15, 2): <gurobi.Var x_station 8,15,2 (value -0.0)>,
#  ('station 1', 16, 1): <gurobi.Var x_station 1,16,1 (value -0.0)>,
#  ('station 2', 16, 1): <gurobi.Var x_station 2,16,1 (value -0.0)>,
#  ('station 3', 16, 1): <gurobi.Var x_station 3,16,1 (value -0.0)>,
#  ('station 4', 16, 1): <gurobi.Var x_station 4,16,1 (value 1.0)>,
#  ('station 5', 16, 1): <gurobi.Var x_station 5,16,1 (value -0.0)>,
#  ('station 6', 16, 1): <gurobi.Var x_station 6,16,1 (value -0.0)>,
#  ('station 7', 16, 1): <gurobi.Var x_station 7,16,1 (value -0.0)>,
#  ('station 8', 16, 1): <gurobi.Var x_station 8,16,1 (value -0.0)>,
#  ('station 1', 16, 2): <gurobi.Var x_station 1,16,2 (value -0.0)>,
#  ('station 2', 16, 2): <gurobi.Var x_station 2,16,2 (value -0.0)>,
#  ('station 3', 16, 2): <gurobi.Var x_station 3,16,2 (value -0.0)>,
#  ('station 4', 16, 2): <gurobi.Var x_station 4,16,2 (value -0.0)>,
#  ('station 5', 16, 2): <gurobi.Var x_station 5,16,2 (value 1.0)>,
#  ('station 6', 16, 2): <gurobi.Var x_station 6,16,2 (value 0.0)>,
#  ('station 7', 16, 2): <gurobi.Var x_station 7,16,2 (value -0.0)>,
#  ('station 8', 16, 2): <gurobi.Var x_station 8,16,2 (value -0.0)>,
#  ('station 1', 17, 1): <gurobi.Var x_station 1,17,1 (value -0.0)>,
#  ('station 2', 17, 1): <gurobi.Var x_station 2,17,1 (value 0.0)>,
#  ('station 3', 17, 1): <gurobi.Var x_station 3,17,1 (value -0.0)>,
#  ('station 4', 17, 1): <gurobi.Var x_station 4,17,1 (value -0.0)>,
#  ('station 5', 17, 1): <gurobi.Var x_station 5,17,1 (value -0.0)>,
#  ('station 6', 17, 1): <gurobi.Var x_station 6,17,1 (value -0.0)>,
#  ('station 7', 17, 1): <gurobi.Var x_station 7,17,1 (value 1.0)>,
#  ('station 8', 17, 1): <gurobi.Var x_station 8,17,1 (value -0.0)>,
#  ('station 1', 17, 2): <gurobi.Var x_station 1,17,2 (value -0.0)>,
#  ('station 2', 17, 2): <gurobi.Var x_station 2,17,2 (value -0.0)>,
#  ('station 3', 17, 2): <gurobi.Var x_station 3,17,2 (value -0.0)>,
#  ('station 4', 17, 2): <gurobi.Var x_station 4,17,2 (value -0.0)>,
#  ('station 5', 17, 2): <gurobi.Var x_station 5,17,2 (value 1.0)>,
#  ('station 6', 17, 2): <gurobi.Var x_station 6,17,2 (value -0.0)>,
#  ('station 7', 17, 2): <gurobi.Var x_station 7,17,2 (value -0.0)>,
#  ('station 8', 17, 2): <gurobi.Var x_station 8,17,2 (value -0.0)>,
#  ('station 1', 18, 1): <gurobi.Var x_station 1,18,1 (value -0.0)>,
#  ('station 2', 18, 1): <gurobi.Var x_station 2,18,1 (value -0.0)>,
#  ('station 3', 18, 1): <gurobi.Var x_station 3,18,1 (value -0.0)>,
#  ('station 4', 18, 1): <gurobi.Var x_station 4,18,1 (value -0.0)>,
#  ('station 5', 18, 1): <gurobi.Var x_station 5,18,1 (value -0.0)>,
#  ('station 6', 18, 1): <gurobi.Var x_station 6,18,1 (value -0.0)>,
#  ('station 7', 18, 1): <gurobi.Var x_station 7,18,1 (value 1.0)>,
#  ('station 8', 18, 1): <gurobi.Var x_station 8,18,1 (value -0.0)>,
#  ('station 1', 18, 2): <gurobi.Var x_station 1,18,2 (value 1.0)>,
#  ('station 2', 18, 2): <gurobi.Var x_station 2,18,2 (value -0.0)>,
#  ('station 3', 18, 2): <gurobi.Var x_station 3,18,2 (value -0.0)>,
#  ('station 4', 18, 2): <gurobi.Var x_station 4,18,2 (value -0.0)>,
#  ('station 5', 18, 2): <gurobi.Var x_station 5,18,2 (value -0.0)>,
#  ('station 6', 18, 2): <gurobi.Var x_station 6,18,2 (value -0.0)>,
#  ('station 7', 18, 2): <gurobi.Var x_station 7,18,2 (value -0.0)>,
#  ('station 8', 18, 2): <gurobi.Var x_station 8,18,2 (value -0.0)>,
#  ('station 1', 19, 1): <gurobi.Var x_station 1,19,1 (value -0.0)>,
#  ('station 2', 19, 1): <gurobi.Var x_station 2,19,1 (value -0.0)>,
#  ('station 3', 19, 1): <gurobi.Var x_station 3,19,1 (value -0.0)>,
#  ('station 4', 19, 1): <gurobi.Var x_station 4,19,1 (value -0.0)>,
#  ('station 5', 19, 1): <gurobi.Var x_station 5,19,1 (value -0.0)>,
#  ('station 6', 19, 1): <gurobi.Var x_station 6,19,1 (value -0.0)>,
#  ('station 7', 19, 1): <gurobi.Var x_station 7,19,1 (value -0.0)>,
#  ('station 8', 19, 1): <gurobi.Var x_station 8,19,1 (value 1.0)>,
#  ('station 1', 19, 2): <gurobi.Var x_station 1,19,2 (value 1.0)>,
#  ('station 2', 19, 2): <gurobi.Var x_station 2,19,2 (value -0.0)>,
#  ('station 3', 19, 2): <gurobi.Var x_station 3,19,2 (value -0.0)>,
#  ('station 4', 19, 2): <gurobi.Var x_station 4,19,2 (value -0.0)>,
#  ('station 5', 19, 2): <gurobi.Var x_station 5,19,2 (value -0.0)>,
#  ('station 6', 19, 2): <gurobi.Var x_station 6,19,2 (value -0.0)>,
#  ('station 7', 19, 2): <gurobi.Var x_station 7,19,2 (value -0.0)>,
#  ('station 8', 19, 2): <gurobi.Var x_station 8,19,2 (value -0.0)>,
#  ('station 1', 20, 1): <gurobi.Var x_station 1,20,1 (value -0.0)>,
#  ('station 2', 20, 1): <gurobi.Var x_station 2,20,1 (value -0.0)>,
#  ('station 3', 20, 1): <gurobi.Var x_station 3,20,1 (value -0.0)>,
#  ('station 4', 20, 1): <gurobi.Var x_station 4,20,1 (value -0.0)>,
#  ('station 5', 20, 1): <gurobi.Var x_station 5,20,1 (value -0.0)>,
#  ('station 6', 20, 1): <gurobi.Var x_station 6,20,1 (value -0.0)>,
#  ('station 7', 20, 1): <gurobi.Var x_station 7,20,1 (value -0.0)>,
#  ('station 8', 20, 1): <gurobi.Var x_station 8,20,1 (value 1.0)>,
#  ('station 1', 20, 2): <gurobi.Var x_station 1,20,2 (value -0.0)>,
#  ('station 2', 20, 2): <gurobi.Var x_station 2,20,2 (value -0.0)>,
#  ('station 3', 20, 2): <gurobi.Var x_station 3,20,2 (value -0.0)>,
#  ('station 4', 20, 2): <gurobi.Var x_station 4,20,2 (value -0.0)>,
#  ('station 5', 20, 2): <gurobi.Var x_station 5,20,2 (value 1.0)>,
#  ('station 6', 20, 2): <gurobi.Var x_station 6,20,2 (value -0.0)>,
#  ('station 7', 20, 2): <gurobi.Var x_station 7,20,2 (value -0.0)>,
#  ('station 8', 20, 2): <gurobi.Var x_station 8,20,2 (value 0.0)>}

# %% [markdown]
# ## Graphing in a circle

# %%
import matplotlib.pyplot as plt
import networkx as nx

truck_paths = {}

# if model.status == GRB.OPTIMAL:
if True:
    for k in range(1, K+1):
        path = []
        for t in range(1, T+1):
            for s in stations:
                if x[s, t, k].x > 0.5:  # If the truck k is at station s at time t
                    path.append((t, s, '{} bikes'.format(int(b[t,k].x))))
                    break
        truck_paths[k] = path
        print(f"Truck {k} path: {path}")
else:
    print("No optimal solution found.")


# Visualize the truck paths
def plot_paths(truck_paths):
    G = nx.DiGraph()
    
    num_stations = len(stations)
    angle_step = 2 * np.pi / num_stations
    radius = 0.1  # You can adjust the radius as needed

    pos = {stations[i]: (np.cos(i * angle_step) * radius, np.sin(i * angle_step) * radius) for i in range(num_stations)}

    # Add nodes
    for station in stations:
        G.add_node(station)
    
    # Add edges with arrows for each truck path
    for k, path in truck_paths.items():
        for i in range(len(path) - 1):
            t1, s1 = path[i][:2]
            t2, s2 = path[i + 1][:2]
            G.add_edge(s1, s2, truck=k, time_step=t1)
    
    edge_colors = ['blue', 'red', 'green', 'purple']  # Different colors for different trucks
    # edge_styles = ['solid', 'dashed']  # Different styles for different trucks
    
    plt.figure(figsize=(10, 8))
    for k, path in truck_paths.items():
        # edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1)]
        # The above includes time steps where the trucks don't move. Below I have removed such trips
        edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1) if path[i][1] != path[i + 1][1]]
        nx.draw_networkx_edges(G, pos, edgelist=edges, arrowstyle='->', arrowsize=15, 
                               edge_color=edge_colors[k - 1], style='dashed', label=f'Truck {k}')
    
    nx.draw_networkx_nodes(G, pos, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, pos, font_size=10)

    from matplotlib.lines import Line2D
    legend_handles = [Line2D([0], [0], color=edge_colors[k - 1], lw=2, label=f'Truck {k}') for k in range(1, K+1)]
    plt.legend(handles=legend_handles)
    
    plt.title("Truck Paths")
    plt.show()

# Plot the paths
plot_paths(truck_paths)
# Out:
# Truck 1 path: [(1, 'station 2', '0 bikes'), (2, 'station 2', '3 bikes'), (3, 'station 3', '3 bikes'), (4, 'station 3', '0 bikes'), (5, 'station 2', '0 bikes'), (6, 'station 2', '3 bikes'), (7, 'station 4', '3 bikes'), (8, 'station 4', '0 bikes'), (9, 'station 2', '0 bikes'), (10, 'station 2', '3 bikes'), (11, 'station 3', '3 bikes'), (12, 'station 3', '0 bikes'), (13, 'station 2', '0 bikes'), (14, 'station 2', '3 bikes'), (15, 'station 3', '3 bikes'), (16, 'station 3', '0 bikes'), (17, 'station 2', '0 bikes'), (18, 'station 2', '3 bikes'), (19, 'station 3', '3 bikes'), (20, 'station 3', '0 bikes')]
# Truck 2 path: [(1, 'station 1', '0 bikes'), (2, 'station 1', '3 bikes'), (3, 'station 4', '3 bikes'), (4, 'station 4', '0 bikes'), (5, 'station 1', '0 bikes'), (6, 'station 1', '3 bikes'), (7, 'station 4', '3 bikes'), (8, 'station 4', '0 bikes'), (9, 'station 1', '0 bikes'), (10, 'station 1', '3 bikes'), (11, 'station 4', '3 bikes'), (12, 'station 4', '0 bikes'), (13, 'station 1', '0 bikes'), (14, 'station 1', '3 bikes'), (15, 'station 4', '3 bikes'), (16, 'station 4', '0 bikes'), (17, 'station 1', '0 bikes'), (18, 'station 1', '3 bikes'), (19, 'station 3', '3 bikes'), (20, 'station 3', '0 bikes')]

# %% [markdown]
# # Graphing Better

# %%
import matplotlib.pyplot as plt
import networkx as nx

truck_paths = {}

# if model.status == GRB.OPTIMAL:
if True:
    for k in range(1, K+1):
        path = []
        for t in range(1, T+1):
            for s in stations:
                if x[s, t, k].x > 0.5:  # If the truck k is at station s at time t
                    path.append((t, s, '{} bikes'.format(int(b[t,k].x))))
                    break
        truck_paths[k] = path
        print(f"Truck {k} path: {path}")
else:
    print("No optimal solution found.")


# Visualize the truck paths
def plot_paths(truck_paths):
    G = nx.DiGraph()
    
    # num_stations = len(stations)
    # side_length = int(np.ceil(np.sqrt(num_stations)))  # Number of nodes along one side of the square
    
    # # Determine the step size to spread nodes evenly in the square
    # step = 2 / (side_length - 1)
    
    # # Generate positions for each node
    # pos = {stations[i]: ((i % side_length) * step - 1, (i // side_length) * step - 1) for i in range(num_stations)}
    
    # Add nodes
    for station in stations:
        G.add_node(station)
    
    # Add edges with arrows for each truck path
    for k, path in truck_paths.items():
        for i in range(len(path) - 1):
            t1, s1 = path[i][:2]
            t2, s2 = path[i + 1][:2]
            G.add_edge(s1, s2, truck=k, time_step=t1)
    
    edge_colors = ['blue', 'red', 'green', 'purple']  # Different colors for different trucks
    # edge_styles = ['solid', 'dashed']  # Different styles for different trucks
    
    plt.figure(figsize=(10, 8))
    for k, path in truck_paths.items():
        # edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1)]
        # The above includes time steps where the trucks don't move. Below I have removed such trips
        edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1) if path[i][1] != path[i + 1][1]]
        nx.draw_networkx_edges(G, positions, edgelist=edges, arrowstyle='->', arrowsize=15, 
                               edge_color=edge_colors[k - 1], style='dashed', label=f'Truck {k}')
    
    nx.draw_networkx_nodes(G, positions, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, positions, font_size=10)

    from matplotlib.lines import Line2D
    legend_handles = [Line2D([0], [0], color=edge_colors[k - 1], lw=2, label=f'Truck {k}') for k in range(1, K+1)]
    plt.legend(handles=legend_handles)
    
    plt.title("Truck Paths")
    plt.show()

# Plot the paths
plot_paths(truck_paths)
# Out:
# Truck 1 path: [(1, 'station 3', '0 bikes'), (2, 'station 3', '3 bikes'), (3, 'station 7', '3 bikes'), (4, 'station 4', '3 bikes'), (5, 'station 1', '3 bikes'), (6, 'station 1', '0 bikes'), (7, 'station 4', '0 bikes'), (8, 'station 6', '0 bikes'), (9, 'station 6', '3 bikes'), (10, 'station 8', '3 bikes'), (11, 'station 8', '0 bikes'), (12, 'station 7', '0 bikes'), (13, 'station 3', '0 bikes'), (14, 'station 3', '3 bikes'), (15, 'station 7', '3 bikes'), (16, 'station 4', '0 bikes'), (17, 'station 7', '0 bikes'), (18, 'station 7', '1 bikes'), (19, 'station 8', '1 bikes'), (20, 'station 8', '0 bikes')]
# Truck 2 path: [(1, 'station 4', '0 bikes'), (2, 'station 4', '3 bikes'), (3, 'station 1', '3 bikes'), (4, 'station 1', '1 bikes'), (5, 'station 4', '1 bikes'), (6, 'station 4', '3 bikes'), (7, 'station 1', '3 bikes'), (8, 'station 1', '0 bikes'), (9, 'station 5', '0 bikes'), (10, 'station 5', '3 bikes'), (11, 'station 8', '3 bikes'), (12, 'station 8', '0 bikes'), (13, 'station 5', '0 bikes'), (14, 'station 5', '3 bikes'), (15, 'station 1', '3 bikes'), (16, 'station 1', '0 bikes'), (17, 'station 4', '0 bikes'), (18, 'station 4', '3 bikes'), (19, 'station 2', '3 bikes'), (20, 'station 2', '0 bikes')]

# %%
# Let's check to see how things changed!

print('Start levels: ', start_levels)
print('Optimal levels: ', optimal_levels)
end_levels = {}
for s in stations:
    end_levels[s] = int(sum(y[s,T,k].x for k in range(1,K+1)))
print('End levels: ', end_levels)

print('\nTotal bikes to start: ', sum(start_levels.values()))
print('Total bikes to end: ', sum(end_levels.values()))
# Out:
# Start levels:  {'station 1': 32, 'station 2': 41, 'station 3': 39, 'station 4': 41, 'station 5': 39, 'station 6': 28, 'station 7': 42, 'station 8': 38}
# Optimal levels:  {'station 1': 45, 'station 2': 44, 'station 3': 33, 'station 4': 36, 'station 5': 33, 'station 6': 23, 'station 7': 41, 'station 8': 45}
# End levels:  {'station 1': 43, 'station 2': 44, 'station 3': 33, 'station 4': 36, 'station 5': 33, 'station 6': 25, 'station 7': 41, 'station 8': 45}
#
# Total bikes to start:  300
# Total bikes to end:  300

# %%
# Number of bikes at each station through time

print('Time 0:', start_levels)
for t in range(1, T+1):
    dict = {}
    for s in stations:
        dict[s] = int(sum(y[s,t,k].x for k in range(1,K+1)))
    print('Time {}:'.format(t), dict)
# Out:
# Time 0: {'station 1': 34, 'station 2': 33, 'station 3': 30, 'station 4': 38, 'station 5': 25, 'station 6': 39, 'station 7': 48, 'station 8': 53}
# Time 1: {'station 1': 34, 'station 2': 33, 'station 3': 30, 'station 4': 38, 'station 5': 25, 'station 6': 39, 'station 7': 48, 'station 8': 53}
# Time 2: {'station 1': 34, 'station 2': 33, 'station 3': 30, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 53}
# Time 3: {'station 1': 34, 'station 2': 33, 'station 3': 30, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 53}
# Time 4: {'station 1': 34, 'station 2': 33, 'station 3': 33, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 53}
# Time 5: {'station 1': 34, 'station 2': 33, 'station 3': 36, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 53}
# Time 6: {'station 1': 34, 'station 2': 33, 'station 3': 36, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 53}
# Time 7: {'station 1': 34, 'station 2': 33, 'station 3': 36, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 45, 'station 8': 50}
# Time 8: {'station 1': 34, 'station 2': 33, 'station 3': 36, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 50}
# Time 9: {'station 1': 34, 'station 2': 33, 'station 3': 39, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 52}
# Time 10: {'station 1': 34, 'station 2': 33, 'station 3': 39, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 49}
# Time 11: {'station 1': 34, 'station 2': 33, 'station 3': 39, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 47}
# Time 12: {'station 1': 34, 'station 2': 33, 'station 3': 42, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 46}
# Time 13: {'station 1': 34, 'station 2': 33, 'station 3': 42, 'station 4': 38, 'station 5': 25, 'station 6': 36, 'station 7': 43, 'station 8': 46}
# Time 14: {'station 1': 34, 'station 2': 33, 'station 3': 42, 'station 4': 38, 'station 5': 27, 'station 6': 36, 'station 7': 43, 'station 8': 43}
# Time 15: {'station 1': 34, 'station 2': 33, 'station 3': 42, 'station 4': 38, 'station 5': 28, 'station 6': 36, 'station 7': 43, 'station 8': 43}
# Time 16: {'station 1': 34, 'station 2': 33, 'station 3': 45, 'station 4': 38, 'station 5': 28, 'station 6': 36, 'station 7': 43, 'station 8': 43}
# Time 17: {'station 1': 34, 'station 2': 33, 'station 3': 45, 'station 4': 38, 'station 5': 28, 'station 6': 36, 'station 7': 43, 'station 8': 43}
# Time 18: {'station 1': 34, 'station 2': 30, 'station 3': 45, 'station 4': 38, 'station 5': 28, 'station 6': 36, 'station 7': 40, 'station 8': 43}
# Time 19: {'station 1': 34, 'station 2': 30, 'station 3': 45, 'station 4': 38, 'station 5': 28, 'station 6': 36, 'station 7': 40, 'station 8': 43}
# Time 20: {'station 1': 34, 'station 2': 30, 'station 3': 45, 'station 4': 41, 'station 5': 31, 'station 6': 36, 'station 7': 40, 'station 8': 43}

# %% [markdown]
# # Animation: Keeps Previous Time Steps

# %%
from IPython.display import HTML  # Import HTML from IPython.display
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import matplotlib.animation as animation

# Function to update the animation at each frame
def update(frame):
    plt.clf()  # Clear previous plot
    G = nx.DiGraph()

    num_stations = len(stations)
    angle_step = 2 * np.pi / num_stations
    radius = 0.3  # Radius for station placement

    pos = {stations[i]: (np.cos(i * angle_step) * radius, np.sin(i * angle_step) * radius) for i in range(num_stations)}

    # Add nodes
    for station in stations:
        G.add_node(station)

    colors = ['blue', 'red']
    
    # Plot edges for each truck's path up to the current frame
    # for k, path in truck_paths.items():
    #     current_path = [p for p in path if p[0] <= frame]
    #     if len(current_path) > 1:
    #         edges = [(current_path[i][1], current_path[i + 1][1]) for i in range(len(current_path) - 1)]
    #         nx.draw_networkx_edges(G, pos, edgelist=edges, arrowstyle='->', arrowsize=15,
    #                                edge_color=colors[k-1], style='dashed', label=f'Truck {k}')

    for k, path in truck_paths.items():
        current_path = [p for p in path if p[0] == frame]
        if len(current_path) > 1:
            edges = [(current_path[i][1], current_path[i + 1][1]) for i in range(len(current_path) - 1)]
            nx.draw_networkx_edges(G, pos, edgelist=edges, arrowstyle='->', arrowsize=15,
                                       edge_color=colors[k-1], style='dashed', label=f'Truck {k}')
    
    nx.draw_networkx_nodes(G, pos, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, pos, font_size=12)
    plt.title(f"Truck Paths at Time Step {frame + 1}")

# Create the animation
fig = plt.figure(figsize=(10, 8))
ani = animation.FuncAnimation(fig, update, frames=T, interval=500, repeat=False)

# Display the animation in the notebook using HTML display
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5ab7eac518f14a239eb424fe449e506c">
#   <div class="anim-controls">
#     <input id="_anim_slider5ab7eac518f14a239eb424fe449e506c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5ab7eac518f14a239eb424fe449e506c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5ab7eac518f14a239eb424fe449e506c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5ab7eac518f14a239eb424fe449e506c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5ab7eac518f14a239eb424fe449e506c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5ab7eac518f14a239eb424fe449e506c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5ab7eac518f14a239eb424fe449e506c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5ab7eac518f14a239eb424fe449e506c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5ab7eac518f14a239eb424fe449e506c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5ab7eac518f14a239eb424fe449e506c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5ab7eac518f14a239eb424fe449e506c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5ab7eac518f14a239eb424fe449e506c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5ab7eac518f14a239eb424fe449e506c"
#              checked>
#       <label for="_anim_radio1_5ab7eac518f14a239eb424fe449e506c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5ab7eac518f14a239eb424fe449e506c"
#              >
#       <label for="_anim_radio2_5ab7eac518f14a239eb424fe449e506c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5ab7eac518f14a239eb424fe449e506c"
#              >
#       <label for="_anim_radio3_5ab7eac518f14a239eb424fe449e506c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5ab7eac518f14a239eb424fe449e506c";
#     var slider_id = "_anim_slider5ab7eac518f14a239eb424fe449e506c";
#     var loop_select_id = "_anim_loop_select5ab7eac518f14a239eb424fe449e506c";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8fJSN1AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABMr0lEQ

# %% [markdown]
# # Only Current Time Steps

# %%
from IPython.display import HTML  # Import HTML from IPython.display
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import matplotlib.animation as animation

num_stations = len(stations)
angle_step = 2 * np.pi / num_stations
radius = 0.3  # Radius for station placement
pos = {stations[i]: (np.cos(i * angle_step) * radius, np.sin(i * angle_step) * radius) for i in range(num_stations)}

# Function to update the animation at each frame
def update(frame):
    plt.clf()  # Clear previous plot
    G = nx.DiGraph()

    # Add nodes
    for station in stations:
        G.add_node(station)

    colors = ['blue', 'red']
    
    # Plot edges for each truck's path at the current frame
    for k, path in truck_paths.items():
        edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1) if path[i][0] == frame]
        if edges:
            nx.draw_networkx_edges(G, pos, edgelist=edges, arrowstyle='->', arrowsize=15,
                                   edge_color=colors[k-1], style='dashed', label=f'Truck {k}')

    nx.draw_networkx_nodes(G, pos, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, pos, font_size=12)
    plt.title(f"Truck Paths at Time Step {frame}")

# Create the animation
fig = plt.figure(figsize=(10, 8))
ani = animation.FuncAnimation(fig, update, frames=range(1, T + 1), interval=500, repeat=False)

# Display the animation in the notebook using HTML display
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge804621bd7ff43ac8d31adb7534c1a54">
#   <div class="anim-controls">
#     <input id="_anim_slidere804621bd7ff43ac8d31adb7534c1a54" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime804621bd7ff43ac8d31adb7534c1a54.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime804621bd7ff43ac8d31adb7534c1a54.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime804621bd7ff43ac8d31adb7534c1a54.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime804621bd7ff43ac8d31adb7534c1a54.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime804621bd7ff43ac8d31adb7534c1a54.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime804621bd7ff43ac8d31adb7534c1a54.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime804621bd7ff43ac8d31adb7534c1a54.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime804621bd7ff43ac8d31adb7534c1a54.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime804621bd7ff43ac8d31adb7534c1a54.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime804621bd7ff43ac8d31adb7534c1a54.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte804621bd7ff43ac8d31adb7534c1a54"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e804621bd7ff43ac8d31adb7534c1a54"
#              checked>
#       <label for="_anim_radio1_e804621bd7ff43ac8d31adb7534c1a54">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e804621bd7ff43ac8d31adb7534c1a54"
#              >
#       <label for="_anim_radio2_e804621bd7ff43ac8d31adb7534c1a54">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e804621bd7ff43ac8d31adb7534c1a54"
#              >
#       <label for="_anim_radio3_e804621bd7ff43ac8d31adb7534c1a54">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge804621bd7ff43ac8d31adb7534c1a54";
#     var slider_id = "_anim_slidere804621bd7ff43ac8d31adb7534c1a54";
#     var loop_select_id = "_anim_loop_selecte804621bd7ff43ac8d31adb7534c1a54";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8fJSN1AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABrrklEQ

# %% [markdown]
# # Without Graphing Stationary Trips

# %%
from IPython.display import HTML  # Import HTML from IPython.display
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import matplotlib.animation as animation


# Calculate positions of the stations once
num_stations = len(stations)
angle_step = 2 * np.pi / num_stations
radius = 0.3  # Radius for station placement
pos = {stations[i]: (np.cos(i * angle_step) * radius, np.sin(i * angle_step) * radius) for i in range(num_stations)}

# Function to update the animation at each frame
def update(frame):
    plt.clf()  # Clear previous plot
    G = nx.DiGraph()

    # Add nodes
    for station in stations:
        G.add_node(station)

    colors = ['blue', 'red', 'green', 'purple']
    
    # Plot edges for each truck's path at the current frame
    for k, path in truck_paths.items():
        edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1) if path[i][0] == frame and path[i][1] != path[i + 1][1]]
        if edges:
            nx.draw_networkx_edges(G, pos, edgelist=edges, arrowstyle='->', arrowsize=15,
                                   edge_color=colors[k-1], style='dashed', label=f'Truck {k}')

    nx.draw_networkx_nodes(G, pos, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, pos, font_size=10)
    plt.title(f"Truck Paths at Time Step {frame}")

# Create the animation
fig = plt.figure(figsize=(10, 8))
ani = animation.FuncAnimation(fig, update, frames=range(1, T + 1), interval=500, repeat=False)

# Display the animation in the notebook using HTML display
HTML(ani.to_jshtml())

# ani.save('truck_paths_animation.html', writer='html')
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img98a2b49e550942838df1b3241c95df84">
#   <div class="anim-controls">
#     <input id="_anim_slider98a2b49e550942838df1b3241c95df84" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim98a2b49e550942838df1b3241c95df84.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim98a2b49e550942838df1b3241c95df84.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim98a2b49e550942838df1b3241c95df84.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim98a2b49e550942838df1b3241c95df84.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim98a2b49e550942838df1b3241c95df84.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim98a2b49e550942838df1b3241c95df84.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim98a2b49e550942838df1b3241c95df84.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim98a2b49e550942838df1b3241c95df84.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim98a2b49e550942838df1b3241c95df84.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim98a2b49e550942838df1b3241c95df84.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select98a2b49e550942838df1b3241c95df84"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_98a2b49e550942838df1b3241c95df84"
#              checked>
#       <label for="_anim_radio1_98a2b49e550942838df1b3241c95df84">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_98a2b49e550942838df1b3241c95df84"
#              >
#       <label for="_anim_radio2_98a2b49e550942838df1b3241c95df84">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_98a2b49e550942838df1b3241c95df84"
#              >
#       <label for="_anim_radio3_98a2b49e550942838df1b3241c95df84">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img98a2b49e550942838df1b3241c95df84";
#     var slider_id = "_anim_slider98a2b49e550942838df1b3241c95df84";
#     var loop_select_id = "_anim_loop_select98a2b49e550942838df1b3241c95df84";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8fJSN1AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABAfklEQ

# %% [markdown]
# # Failed attempt at distance

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np

stations = ['station 1', 'station 2', 'station 3', 'station 4', 'station 5']
start_levels = {'station 1': 12, 'station 2': 18, 'station 3': 12, 'station 4': 18, 'station 5': 15}
optimal_levels = {'station 1': 15, 'station 2': 15, 'station 3': 15, 'station 4': 15, 'station 5': 15}
over_stations, under_stations = [], []

# Fill over and under stations
for station in stations:
    if start_levels[station] > optimal_levels[station]:
        over_stations.append(station)
    elif start_levels[station] < optimal_levels[station]:
        under_stations.append(station)
        
T = 20 # Number of time steps
K = 1 # Number of trucks
L = 3 # Number of bikes that can be moved in one time step

# Distance matrix (time steps between stations)
distances = {
    ('station 1', 'station 1'): 1, ('station 1', 'station 2'): 1, ('station 1', 'station 3'): 1, ('station 1', 'station 4'): 3, ('station 1', 'station 5'): 1,
    ('station 2', 'station 1'): 1, ('station 2', 'station 2'): 1, ('station 2', 'station 3'): 1, ('station 2', 'station 4'): 3, ('station 2', 'station 5'): 1,
    ('station 3', 'station 1'): 1, ('station 3', 'station 2'): 1, ('station 3', 'station 3'): 1, ('station 3', 'station 4'): 3, ('station 3', 'station 5'): 1,
    ('station 4', 'station 1'): 3, ('station 4', 'station 2'): 3, ('station 4', 'station 3'): 3, ('station 4', 'station 4'): 1, ('station 4', 'station 5'): 3,
    ('station 5', 'station 1'): 1, ('station 5', 'station 2'): 1, ('station 5', 'station 3'): 1, ('station 5', 'station 4'): 3, ('station 5', 'station 5'): 1
    }

model = gp.Model("bike_rebalancing")

# Decision variables
x, y, b = {}, {}, {}
for t in range(1, T+1):
    for k in range(1, K+1):
        for s in stations:
            x[s, t, k] = model.addVar(name="x_%s,%s,%s" % (s, t, k), vtype=GRB.BINARY)
            y[s, t, k] = model.addVar(name="y_%s,%s,%s" % (s, t, k), vtype=GRB.INTEGER)
        b[t, k] = model.addVar(name="b_%s,%s" % (t, k), vtype=GRB.INTEGER)

# Previous station decision variable
p = {}
for t in range(2, T+1):
    for k in range(1, K+1):
        for s1 in stations:
            for s2 in stations:
                p[s1, s2, t, k] = model.addVar(name="p_%s,%s,%s,%s" % (s1, s2, t, k), vtype=GRB.BINARY)

# Auxiliary variables for absolute deviation
deviation = {}
for s in stations:
    deviation[s] = model.addVar(name="deviation_%s" % s, vtype=GRB.INTEGER)

model.update()

# Objective function: minimize total absolute deviation from optimal levels
objective = gp.quicksum(deviation[s] for s in stations)
model.setObjective(objective, sense=GRB.MINIMIZE)

# Constraints

# Each truck must be at exactly 1 station always
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(x[s, t, k] for s in stations) == 1)

# Initialize bike levels at time 1
for s in stations:
    model.addConstr(sum(y[s, 1, k] for k in range(1, K+1)) == start_levels[s])

# Rebalancing can only bring a station closer to optimal level
for t in range(1, T+1):
    for s in over_stations:
        model.addConstr(optimal_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= start_levels[s])
    for s in under_stations:
        model.addConstr(start_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= optimal_levels[s])

# Total number of bikes is constant
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(y[s, t, k] for s in stations) + b[t, k] == sum(y[s, 1, k] for s in stations) + b[1, k])

# Can move only when truck is at station; number of bikes moved is bounded
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(y[s, t, k] - y[s, t-1, k] <= L * gp.quicksum(p[s1, s, t, k] for s1 in stations))
            model.addConstr(y[s, t-1, k] - y[s, t, k] <= L * gp.quicksum(p[s1, s, t, k] for s1 in stations))

# Constraint 8 in paper
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in over_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L + (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L - (y[s,t,k] - y[s,t-1,k]))
        for s in under_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L - (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L + (y[s,t,k] - y[s,t-1,k]))


# Ensure each truck is at one station per time step
for t in range(2, T+1):
    for k in range(1, K+1):
        for s1 in stations:
            model.addConstr(gp.quicksum(p[s1, s2, t, k] for s2 in stations) == x[s1, t-1, k])
            model.addConstr(gp.quicksum(p[s2, s1, t, k] for s2 in stations) == x[s1, t, k])

# Ensure trucks respect travel times
for t in range(2, T+1):
    for k in range(1, K+1):
        for s1 in stations:
            for s2 in stations:
                if distances[s1, s2] > (t - (t-1)):
                    model.addConstr(p[s1, s2, t, k] == 0)

# Ensure each truck travels within allowed time steps between stations
for t in range(2, T+1):
    for k in range(1, K+1):
        for s1 in stations:
            for s2 in stations:
                if distances[s1, s2] <= 1:
                    model.addConstr(p[s1, s2, t, k] <= x[s1, t-1, k] * x[s2, t, k])
                else:
                    model.addConstr(p[s1, s2, t, k] == 0)

# Absolute deviation constraints
for s in stations:
    model.addConstr(deviation[s] >= optimal_levels[s] - sum(y[s, T, k] for k in range(1, K+1)))
    model.addConstr(deviation[s] >= sum(y[s, T, k] for k in range(1, K+1)) - optimal_levels[s])

model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 17.7.0 17G14042)
#
# CPU model: Intel(R) Core(TM) i5-4250U CPU @ 1.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[64], line 133
#     130     model.addConstr(deviation[s] >= optimal_levels[s] - sum(y[s, T, k] for k in range(1, K+1)))
#     131     model.addConstr(deviation[s] >= sum(y[s, T, k] for k in range(1, K+1)) - optimal_levels[s])
# --> 133 model.optimize()
#
# File src/gurobipy/model.pxi:893, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information

# %% [markdown]
# # Trying to do stuff w/ the model

# %%
# copying a bunch of stuff from cluster_model

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import urllib.request
import simplejson
from cluster_model import ClusterModel
from datetime import timedelta
import pickle
import seaborn as sns

# %%
with open('/Users/Timothy/Documents/CSUREMM-main/data/data.pickle', 'rb') as f:
    station_data = pickle.load(f)

cluster_model = ClusterModel(station_data=station_data, in_transit=[], tph=4)
stations = [station for station in cluster_model.station_data.keys()]

# %%
start_levels, optimal_levels = {}, {}
for station in stations:
    start_levels[station] = 0
    optimal_levels[station] = 0

start_levels['5th Ave & E 63 St'] = 3
optimal_levels['5th Ave & E 72 St'] = 3

neighbors = {}
for s in stations:
    limit = 0.05
    neighbors[s] = [s1 for s1 in stations if np.linalg.norm(np.array(positions[s] - np.array(positions[s1]))) < L]

T = 20
K = 1
L = 3

# %%
over_stations, under_stations, balanced_stations = [], [], []
# Fill over and under stations
for station in stations:
    if start_levels[station] > optimal_levels[station]:
        over_stations.append(station)
    elif start_levels[station] < optimal_levels[station]:
        under_stations.append(station)
    else:
        balanced_stations.append(station)
        
# T = 20 # Number of time steps
# K = 2 # Number of trucks
# L = 3 # Number of bikes that can be moved in one time step

model = gp.Model("bike_rebalancing")

# Decision variables
x, y, b = {}, {}, {}
for t in range(1, T+1):
    for k in range(1, K+1):
        for s in stations:
            x[s, t, k] = model.addVar(name="x_%s,%s,%s" % (s, t, k), vtype=GRB.BINARY)
            y[s, t, k] = model.addVar(name="y_%s,%s,%s" % (s, t, k), vtype=GRB.INTEGER)
        b[t, k] = model.addVar(name="b_%s,%s" % (t, k), vtype=GRB.INTEGER)

# Auxiliary variables for absolute deviation
deviation = {}
for s in stations:
    deviation[s] = model.addVar(name="deviation_%s" % s, vtype=GRB.INTEGER)

model.update()

# Objective function: minimize total absolute deviation from optimal levels
objective = gp.quicksum(deviation[s] for s in stations)
model.setObjective(objective, sense=GRB.MINIMIZE)

# Constraints:

# Constraint 1: can only move to an adjacent station
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(x[s,t,k] <= x[s,t-1,k] + gp.quicksum(x[s1,t-1,k] for s1 in neighbors[s]))


# Constraint 2: each truck must be at exactly 1 station always
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(x[s, t, k] for s in stations) == 1)

# Constraint 3: initialize bike levels at time 1
for s in stations:
    model.addConstr(sum(y[s, 1, k] for k in range(1, K+1)) == start_levels[s])

# Constraint 4 & 5: rebalancing can only bring a station closer to optimal level
for t in range(1, T+1):
    for s in over_stations:
        model.addConstr(optimal_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= start_levels[s])
    for s in under_stations:
        model.addConstr(start_levels[s] <= sum(y[s, t, k] for k in range(1, K+1)))
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) <= optimal_levels[s])
    for s in balanced_stations:
        model.addConstr(sum(y[s, t, k] for k in range(1, K+1)) == start_levels[s])

# Constraint 6: total number of bikes is constant
for t in range(1, T+1):
    for k in range(1, K+1):
        model.addConstr(sum(y[s, t, k] for s in stations) + b[t, k] == sum(y[s, 1, k] for s in stations) + b[1, k])

# Constraint 7: can move only when truck is at station; number of bikes moved is bounded
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in stations:
            model.addConstr(y[s, t, k] - y[s, t-1, k] <= L * x[s, t, k])
            model.addConstr(y[s, t-1, k] - y[s, t, k] <= L * x[s, t, k])

# Constraint 8: can either travel or load/unload, not both
for t in range(2, T+1):
    for k in range(1, K+1):
        for s in over_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L + (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L - (y[s,t,k] - y[s,t-1,k]))
        for s in under_stations:
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) <= L - (y[s,t,k] - y[s,t-1,k]))
            model.addConstr(L * (x[s,t,k] - x[s,t-1,k]) >= -L + (y[s,t,k] - y[s,t-1,k]))

# TEST: each truck can only house L bikes
for k in range(1, K+1):
    for t in range(1,T+1):
        model.addConstr(b[t,k] <= L)

# Absolute deviation constraints
for s in stations:
    model.addConstr(deviation[s] >= optimal_levels[s] - sum(y[s, T, k] for k in range(1, K+1)))
    model.addConstr(deviation[s] >= sum(y[s, T, k] for k in range(1, K+1)) - optimal_levels[s])

# At beginning and end, there must be no bikes in trucks
model.addConstr(gp.quicksum(b[T, k] for k in range(1, K+1)) == 0)
model.addConstr(gp.quicksum(b[1, k] for k in range(1, K+1)) == 0)

model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 17.7.0 17G14042)
#
# CPU model: Intel(R) Core(TM) i5-4250U CPU @ 1.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[40], line 102
#      99 model.addConstr(gp.quicksum(b[T, k] for k in range(1, K+1)) == 0)
#     100 model.addConstr(gp.quicksum(b[1, k] for k in range(1, K+1)) == 0)
# --> 102 model.optimize()
#
# File src/gurobipy/model.pxi:893, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information

# %%
for v in model.getVars():
    print(f"{v.varName}: {v.x}")
# Out:
# x_station 1,1,1: 0.0
# y_station 1,1,1: 0.0
# x_station 2,1,1: 0.0
# y_station 2,1,1: 0.0
# x_station 3,1,1: 0.0
# y_station 3,1,1: 0.0
# x_station 4,1,1: 0.0
# y_station 4,1,1: 0.0
# x_station 5,1,1: 0.0
# y_station 5,1,1: 0.0
# x_station 6,1,1: 0.0
# y_station 6,1,1: 0.0
# x_station 7,1,1: 1.0
# y_station 7,1,1: 0.0
# x_station 8,1,1: 0.0
# y_station 8,1,1: 0.0
# b_1,1: 0.0
# x_station 1,2,1: 1.0
# y_station 1,2,1: 0.0
# x_station 2,2,1: 0.0
# y_station 2,2,1: 0.0
# x_station 3,2,1: 0.0
# y_station 3,2,1: 0.0
# x_station 4,2,1: 0.0
# y_station 4,2,1: 0.0
# x_station 5,2,1: 0.0
# y_station 5,2,1: 0.0
# x_station 6,2,1: 0.0
# y_station 6,2,1: 0.0
# x_station 7,2,1: 0.0
# y_station 7,2,1: 0.0
# x_station 8,2,1: 0.0
# y_station 8,2,1: 0.0
# b_2,1: 0.0
# x_station 1,3,1: 0.0
# y_station 1,3,1: 0.0
# x_station 2,3,1: 0.0
# y_station 2,3,1: 0.0
# x_station 3,3,1: 0.0
# y_station 3,3,1: 0.0
# x_station 4,3,1: 0.0
# y_station 4,3,1: 0.0
# x_station 5,3,1: 1.0
# y_station 5,3,1: 0.0
# x_station 6,3,1: 0.0
# y_station 6,3,1: 0.0
# x_station 7,3,1: 0.0
# y_station 7,3,1: 0.0
# x_station 8,3,1: 0.0
# y_station 8,3,1: 0.0
# b_3,1: 0.0
# x_station 1,4,1: 0.0
# y_station 1,4,1: 0.0
# x_station 2,4,1: 0.0
# y_station 2,4,1: 0.0
# x_station 3,4,1: 0.0
# y_station 3,4,1: 0.0
# x_station 4,4,1: 0.0
# y_station 4,4,1: 0.0
# x_station 5,4,1: 0.0
# y_station 5,4,1: 0.0
# x_station 6,4,1: 0.0
# y_station 6,4,1: 0.0
# x_station 7,4,1: 1.0
# y_station 7,4,1: 0.0
# x_station 8,4,1: 0.0
# y_station 8,4,1: 0.0
# b_4,1: 0.0
# x_station 1,5,1: 0.0
# y_station 1,5,1: 0.0
# x_station 2,5,1: 1.0
# y_station 2,5,1: 0.0
# x_station 3,5,1: 0.0
# y_station 3,5,1: 0.0
# x_station 4,5,1: 0.0
# y_station 4,5,1: 0.0
# x_station 5,5,1: 0.0
# y_station 5,5,1: 0.0
# x_station 6,5,1: 0.0
# y_station 6,5,1: 0.0
# x_station 7,5,1: 0.0
# y_station 7,5,1: 0.0
# x_station 8,5,1: 0.0
# y_station 8,5,1: 0.0
# b_5,1: 0.0
# x_station 1,6,1: 0.0
# y_station 1,6,1: 0.0
# x_station 2,6,1: 0.0
# y_station 2,6,1: 0.0
# x_station 3,6,1: 0.0
# y_station 3,6,1: 0.0
# x_station 4,6,1: 0.0
# y_station 4,6,1: 0.0
# x_station 5,6,1: 0.0
# y_station 5,6,1: 0.0
# x_station 6,6,1: 1.0
# y_station 6,6,1: 0.0
# x_station 7,6,1: 0.0
# y_station 7,6,1: 0.0
# x_station 8,6,1: 0.0
# y_station 8,6,1: 0.0
# b_6,1: 0.0
# x_station 1,7,1: 0.0
# y_station 1,7,1: 0.0
# x_station 2,7,1: 0.0
# y_station 2,7,1: 0.0
# x_station 3,7,1: 0.0
# y_station 3,7,1: 0.0
# x_station 4,7,1: 0.0
# y_station 4,7,1: 0.0
# x_station 5,7,1: 0.0
# y_station 5,7,1: 0.0
# x_station 6,7,1: 0.0
# y_station 6,7,1: 0.0
# x_station 7,7,1: 1.0
# y_station 7,7,1: 0.0
# x_station 8,7,1: 0.0
# y_station 8,7,1: 0.0
# b_7,1: 0.0
# x_station 1,8,1: 1.0
# y_station 1,8,1: 0.0
# x_station 2,8,1: 0.0
# y_station 2,8,1: 0.0
# x_station 3,8,1: 0.0
# y_station 3,8,1: 0.0
# x_station 4,8,1: 0.0
# y_station 4,8,1: 0.0
# x_station 5,8,1: 0.0
# y_station 5,8,1: 0.0
# x_station 6,8,1: 0.0
# y_station 6,8,1: 0.0
# x_station 7,8,1: 0.0
# y_station 7,8,1: 0.0
# x_station 8,8,1: 0.0
# y_station 8,8,1: 0.0
# b_8,1: 0.0
# x_station 1,9,1: 1.0
# y_station 1,9,1: 0.0
# x_station 2,9,1: 0.0
# y_station 2,9,1: 0.0
# x_station 3,9,1: 0.0
# y_station 3,9,1: 0.0
# x_station 4,9,1: 0.0
# y_station 4,9,1: 0.0
# x_station 5,9,1: 0.0
# y_station 5,9,1: 0.0
# x_station 6,9,1: 0.0
# y_station 6,9,1: 0.0
# x_station 7,9,1: 0.0
# y_station 7,9,1: 0.0
# x_station 8,9,1: 0.0
# y_station 8,9,1: 0.0
# b_9,1: 0.0
# x_station 1,10,1: 0.0
# y_station 1,10,1: 0.0
# x_station 2,10,1: 0.0
# y_station 2,10,1: 0.0
# x_station 3,10,1: 0.0
# y_station 3,10,1: 0.0
# x_station 4,10,1: 0.0
# y_station 4,10,1: 0.0
# x_station 5,10,1: 0.0
# y_station 5,10,1: 0.0
# x_station 6,10,1: 0.0
# y_station 6,10,1: 0.0
# x_station 7,10,1: 0.0
# y_station 7,10,1: 0.0
# x_station 8,10,1: 1.0
# y_station 8,10,1: 0.0
# b_10,1: 0.0
# x_station 1,11,1: 0.0
# y_station 1,11,1: 0.0
# x_station 2,11,1: 0.0
# y_station 2,11,1: 0.0
# x_station 3,11,1: 0.0
# y_station 3,11,1: 0.0
# x_station 4,11,1: 0.0
# y_station 4,11,1: 0.0
# x_station 5,11,1: 1.0
# y_station 5,11,1: 0.0
# x_station 6,11,1: 0.0
# y_station 6,11,1: 0.0
# x_station 7,11,1: 0.0
# y_station 7,11,1: 0.0
# x_station 8,11,1: 0.0
# y_station 8,11,1: 0.0
# b_11,1: 0.0
# x_station 1,12,1: 0.0
# y_station 1,12,1: 0.0
# x_station 2,12,1: 0.0
# y_station 2,12,1: 0.0
# x_station 3,12,1: 0.0
# y_station 3,12,1: 0.0
# x_station 4,12,1: 1.0
# y_station 4,12,1: 0.0
# x_station 5,12,1: 0.0
# y_station 5,12,1: 0.0
# x_station 6,12,1: 0.0
# y_station 6,12,1: 0.0
# x_station 7,12,1: 0.0
# y_station 7,12,1: 0.0
# x_station 8,12,1: 0.0
# y_station 8,12,1: 0.0
# b_12,1: 0.0
# x_station 1,13,1: 0.0
# y_station 1,13,1: 0.0
# x_station 2,13,1: 0.0
# y_station 2,13,1: 0.0
# x_station 3,13,1: 0.0
# y_station 3,13,1: 0.0
# x_station 4,13,1: 0.0
# y_station 4,13,1: 0.0
# x_station 5,13,1: 1.0
# y_station 5,13,1: 0.0
# x_station 6,13,1: 0.0
# y_station 6,13,1: 0.0
# x_station 7,13,1: 0.0
# y_station 7,13,1: 0.0
# x_station 8,13,1: 0.0
# y_station 8,13,1: 0.0
# b_13,1: 0.0
# x_station 1,14,1: 0.0
# y_station 1,14,1: 0.0
# x_station 2,14,1: 1.0
# y_station 2,14,1: 0.0
# x_station 3,14,1: 0.0
# y_station 3,14,1: 0.0
# x_station 4,14,1: 0.0
# y_station 4,14,1: 0.0
# x_station 5,14,1: 0.0
# y_station 5,14,1: 0.0
# x_station 6,14,1: 0.0
# y_station 6,14,1: 0.0
# x_station 7,14,1: 0.0
# y_station 7,14,1: 0.0
# x_station 8,14,1: 0.0
# y_station 8,14,1: 0.0
# b_14,1: 0.0
# x_station 1,15,1: 0.0
# y_station 1,15,1: 0.0
# x_station 2,15,1: 0.0
# y_station 2,15,1: 0.0
# x_station 3,15,1: 0.0
# y_station 3,15,1: 0.0
# x_station 4,15,1: 0.0
# y_station 4,15,1: 0.0
# x_station 5,15,1: 1.0
# y_station 5,15,1: 0.0
# x_station 6,15,1: 0.0
# y_station 6,15,1: 0.0
# x_station 7,15,1: 0.0
# y_station 7,15,1: 0.0
# x_station 8,15,1: 0.0
# y_station 8,15,1: 0.0
# b_15,1: 0.0
# x_station 1,16,1: 0.0
# y_station 1,16,1: 0.0
# x_station 2,16,1: 0.0
# y_station 2,16,1: 0.0
# x_station 3,16,1: 0.0
# y_station 3,16,1: 0.0
# x_station 4,16,1: 0.0
# y_station 4,16,1: 0.0
# x_station 5,16,1: 1.0
# y_station 5,16,1: 0.0
# x_station 6,16,1: 0.0
# y_station 6,16,1: 0.0
# x_station 7,16,1: 0.0
# y_station 7,16,1: 0.0
# x_station 8,16,1: 0.0
# y_station 8,16,1: 0.0
# b_16,1: 0.0
# x_station 1,17,1: 0.0
# y_station 1,17,1: 0.0
# x_station 2,17,1: 0.0
# y_station 2,17,1: 0.0
# x_station 3,17,1: 0.0
# y_station 3,17,1: 0.0
# x_station 4,17,1: 0.0
# y_station 4,17,1: 0.0
# x_station 5,17,1: 1.0
# y_station 5,17,1: 0.0
# x_station 6,17,1: 0.0
# y_station 6,17,1: 0.0
# x_station 7,17,1: 0.0
# y_station 7,17,1: 0.0
# x_station 8,17,1: 0.0
# y_station 8,17,1: 0.0
# b_17,1: 0.0
# x_station 1,18,1: 0.0
# y_station 1,18,1: 0.0
# x_station 2,18,1: 1.0
# y_station 2,18,1: 0.0
# x_station 3,18,1: 0.0
# y_station 3,18,1: 0.0
# x_station 4,18,1: 0.0
# y_station 4,18,1: 0.0
# x_station 5,18,1: 0.0
# y_station 5,18,1: 0.0
# x_station 6,18,1: 0.0
# y_station 6,18,1: 0.0
# x_station 7,18,1: 0.0
# y_station 7,18,1: 0.0
# x_station 8,18,1: 0.0
# y_station 8,18,1: 0.0
# b_18,1: 0.0
# x_station 1,19,1: 1.0
# y_station 1,19,1: 0.0
# x_station 2,19,1: 0.0
# y_station 2,19,1: 0.0
# x_station 3,19,1: 0.0
# y_station 3,19,1: 0.0
# x_station 4,19,1: 0.0
# y_station 4,19,1: 0.0
# x_station 5,19,1: 0.0
# y_station 5,19,1: 0.0
# x_station 6,19,1: 0.0
# y_station 6,19,1: 0.0
# x_station 7,19,1: 0.0
# y_station 7,19,1: 0.0
# x_station 8,19,1: 0.0
# y_station 8,19,1: 0.0
# b_19,1: 0.0
# x_station 1,20,1: 1.0
# y_station 1,20,1: 0.0
# x_station 2,20,1: 0.0
# y_station 2,20,1: 0.0
# x_station 3,20,1: 0.0
# y_station 3,20,1: 0.0
# x_station 4,20,1: 0.0
# y_station 4,20,1: 0.0
# x_station 5,20,1: 0.0
# y_station 5,20,1: 0.0
# x_station 6,20,1: 0.0
# y_station 6,20,1: 0.0
# x_station 7,20,1: 0.0
# y_station 7,20,1: 0.0
# x_station 8,20,1: 0.0
# y_station 8,20,1: 0.0
# b_20,1: 0.0
# deviation_station 1: 0.0
# deviation_station 2: 0.0
# deviation_station 3: 0.0
# deviation_station 4: 0.0
# deviation_station 5: 0.0
# deviation_station 6: 0.0
# deviation_station 7: 0.0
# deviation_station 8: 0.0

# %%
lons = []
lats = []

for station in stations:
    lons.append(station_data[station]['lon'])
    lats.append(station_data[station]['lat'])

min_lat = min(lats)
max_lat = max(lats)
min_lon = min(lons)
max_lon = max(lons)

def shift(x,y):
    x1 = -1 + ((x - min(lons)) * 2 / (max(lons)-min(lons)))
    y1 = -1 + ((y - min(lats)) * 2 / (max(lats)-min(lats)))  
    return(x1, y1)

# stations = [station for station in cluster_model.station_data.keys()] ... defined earlier
positions = {}
for station in stations:
    lon = station_data[station]['lon']
    lat = station_data[station]['lat']
    x,y = shift(lon, lat)
    positions[station] = (x,y)

# %%
import matplotlib.pyplot as plt
import networkx as nx

truck_paths = {}

# if model.status == GRB.OPTIMAL:
if True:
    for k in range(1, K+1):
        path = []
        for t in range(1, T+1):
            for s in stations:
                if x[s, t, k].x > 0.5:  # If the truck k is at station s at time t
                    path.append((t, s, '{} bikes'.format(int(b[t,k].x))))
                    break
        truck_paths[k] = path
        print(f"Truck {k} path: {path}")
else:
    print("No optimal solution found.")


# Visualize the truck paths
def plot_paths(truck_paths):
    G = nx.DiGraph()
    
    # num_stations = len(stations)
    # side_length = int(np.ceil(np.sqrt(num_stations)))  # Number of nodes along one side of the square
    
    # # Determine the step size to spread nodes evenly in the square
    # step = 2 / (side_length - 1)
    
    # # Generate positions for each node
    # pos = {stations[i]: ((i % side_length) * step - 1, (i // side_length) * step - 1) for i in range(num_stations)}
    
    # Add nodes
    for station in stations:
        G.add_node(station)
    
    # Add edges with arrows for each truck path
    for k, path in truck_paths.items():
        for i in range(len(path) - 1):
            t1, s1 = path[i][:2]
            t2, s2 = path[i + 1][:2]
            G.add_edge(s1, s2, truck=k, time_step=t1)
    
    edge_colors = ['blue', 'red', 'green', 'purple']  # Different colors for different trucks
    # edge_styles = ['solid', 'dashed']  # Different styles for different trucks
    
    plt.figure(figsize=(10, 8))
    for k, path in truck_paths.items():
        # edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1)]
        # The above includes time steps where the trucks don't move. Below I have removed such trips
        edges = [(path[i][1], path[i + 1][1]) for i in range(len(path) - 1) if path[i][1] != path[i + 1][1]]
        nx.draw_networkx_edges(G, positions, edgelist=edges, arrowstyle='->', arrowsize=15, 
                               edge_color=edge_colors[k - 1], style='dashed', label=f'Truck {k}')
    
    nx.draw_networkx_nodes(G, positions, node_size=500, node_color='lightgray')
    nx.draw_networkx_labels(G, positions, font_size=10)

    from matplotlib.lines import Line2D
    legend_handles = [Line2D([0], [0], color=edge_colors[k - 1], lw=2, label=f'Truck {k}') for k in range(1, K+1)]
    plt.legend(handles=legend_handles)
    
    plt.title("Truck Paths")
    plt.show()

# Plot the paths
plot_paths(truck_paths)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 12
#      10 for t in range(1, T+1):
#      11     for s in stations:
# ---> 12         if x[s, t, k].x > 0.5:  # If the truck k is at station s at time t
#      13             path.append((t, s, '{} bikes'.format(int(b[t,k].x))))
#      14             break
#
# IndexError: invalid index to scalar variable.
