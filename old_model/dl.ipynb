# %%
import simplejson

# %%
with open('data/2024-07-09-10-00.pickle', 'r') as f:
    data = simplejson.load(f)

# %%
file[:-7]
# Out:
# '2024-07-09-10-00'

# %%
all_data = {}
all_data[file[:-7]] = data['data']['stations']

# %%
data['data']['stations']
# Out:
# [{'num_docks_disabled': 0,
#   'num_bikes_available': 0,
#   'vehicle_types_available': [{'count': 0, 'vehicle_type_id': '1'},
#    {'count': 0, 'vehicle_type_id': '2'}],
#   'num_ebikes_available': 0,
#   'station_id': 'c1a4d909-0a00-475a-8e82-18ed13a4eb01',
#   'is_installed': 0,
#   'is_renting': 0,
#   'is_returning': 0,
#   'num_docks_available': 0,
#   'num_bikes_disabled': 0,
#   'last_reported': 1717071330},
#  {'num_docks_disabled': 0,
#   'num_bikes_available': 0,
#   'vehicle_types_available': [{'count': 0, 'vehicle_type_id': '1'},
#    {'count': 0, 'vehicle_type_id': '2'}],
#   'num_ebikes_available': 0,
#   'station_id': '40043e8a-6ef6-428d-b585-a7c23cdb06d4',
#   'is_installed': 0,
#   'is_renting': 0,
#   'is_returning': 0,
#   'num_docks_available': 0,
#   'num_bikes_disabled': 0,
#   'last_reported': 1717166623},
#  {'num_docks_disabled': 0,
#   'num_bikes_available': 0,
#   'vehicle_types_available': [{'count': 0, 'vehicle_type_id': '1'},
# ...
